# %% [markdown]
# ## Alpha Zero for Gomoku
#
# In this seminar we look at an implementation of [Alpha Zero](https://kstatic.googleusercontent.com/files/2f51b2a749a284c2e2dfa13911da965f4855092a179469aedd15fbe4efe8f8cbf9c515ef83ac03a6515fa990e6f85fd827dcd477845e806f23a17845072dc7bd). Technically, we look at its predecessor, a version specialized to Go called [AlphaGo Zero](https://www.nature.com/articles/nature24270).
#
# In the lecture we spoke about AlphaGo. A review of AlphaGo pipeline:

# %% [markdown]
# ## AlphaGo Pipeline
#
# <center>
#   <figure>
#     <img src="images/pipeline1.png" width=800>
#     <figcaption>
#       Policy and value networks.
#     </figcaption>
#   </figure>
# </center>
#
# <center>
#   <figure>
#     <img src="images/pipeline2.png" width=800>
#     <figcaption>
#       An Illustration of MCTS.
#     </figcaption>
#   </figure>
# </center>

# %% [markdown]
# ## AlphaGo Zero
#
# ### Differences between AlphaGo and AlphaGo Zero
#
# * AlphaGo uses supervised learning from human expert moves whereas AlphaGo Zero is solely based on reinforcement learning, without human data, guidance or domain knowledge beyond game rules.
# * AlphaGo trains the policy and value networks separately whereas AlphaGo Zero uses a single neural network.
# * AlphaGo Zero uses Monte-Carlo tree search as a policy improvement step to simulate data trajectories (according to UCB) and Monte Carlo evaluation as a policy evaluation step to update the policy and value network. It repeats this procedure to improve the policy and value network (similar to policy iteration).
#
# ### Monte-Carlo-Tree-Search
#
# <center>
#   <figure>
#     <img src="images/MCTS.png" width=800>
#     <figcaption>
#       Taken from DeepMind. Great depiction of MCTS.
#     </figcaption>
#   </figure>
# </center>
#
# Once the Tree Search is finished we collect tree search values $z$ and tree search probabilities $\pi$ for all the nodes in the search tree.
#
# ### Self-Play
#
# <center>
#   <figure>
#     <img src="images/self_play.png" width=800>
#     <figcaption>
#       Taken from DeepMind
#     </figcaption>
#   </figure>
# </center>
#
# The model plays against itself which is depicted above. Given a certain game state the algorithm performs a MTCS to generate the tree search probabilities $\pi$. An action is then sampled from $\pi$ which brings us in the next state. Again, perform a MTCS and so on. This goes on until the game is finished. The tree search reward $z$ is collected.
#
#
# ### Training
#
# <center>
#   <figure>
#     <img src="images/training.png" width=800>
#     <figcaption>
#       Taken from DeepMind
#     </figcaption>
#   </figure>
# </center>
#
# $$L_{value} = (z - V)^2.$$
#
# This is the squared loss induced by wrong prediction of the value functions at the experienced states.
#
# The loss corresponding to the actions is
#
# $$L_{action} = - \pi^\top \log p.$$
#
# The loss is large if the tree search probabilities $\pi$ are very different from the network probabilities $p$ and is minimized if $\pi = p$. The function $\pi$ is generated by the MCTS where the initial update probabilities $p$ are modified to account for experienced Monte-Carlo $Q$ functions and stimulate exploration by using upper confidence bounds (recall our use of these in Seminar 1 when discussing $k$-bandit problems).
#
# The regularization loss is defined as
#
# $$L_{reg} = c \|\theta\|^2$$
#
# for some constant $c$ and the current network parameters $\theta$.
#
# The overall loss is defined as
#
# $$L = L_{value} + L_{action} + L_{reg}.$$

# %% [markdown]
# ## Gomoku
#
# The implementation we use is applied to the game of [Gomoku](https://en.wikipedia.org/wiki/Gomoku).
#
# <center>
#   <figure>
#     <img src="images/gomoku.jpg" width=300>
#     <figcaption>
#       Typical game state in Gomoku
#     </figcaption>
#   </figure>
# </center>
#
# Gomoku is a 2-player game where players alternatingly place stones on a square board. The aim of the game is to position $k$ consecutive stones horizontally, vertically or diagonally.
#
# Gomoku is a much easier game than Go and board sizes up to 10 x 10 are suitable for a standard CPU to develop a good model in a few days.
#
# Let us begin by playing a round on an 8x8 board where the target is to get 5 consecutive stones. The MCTS Model used was trained for a few days on a standard CPU.

# %%
from play import run
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.8.18)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# %%capture
run(width=8, height=8, num_consecutive=5)

# %% [markdown]
# The current AI good but still far from optimal:
#
# <center>
#   <figure>
#     <img src="images/win_against_8_8_5.png" width=300>
#     <figcaption>
#       Implemented Graphical User Interface: Winning against the current 8x8 and 5 consecutive stones.
#     </figcaption>
#   </figure>
# </center>

# %% [markdown]
# ### The network architecture
#
# #### Input
#
# ```python
# self.board_width = board_width
# self.board_height = board_height
#
# # Define the tensorflow neural network
# # 1. Input:
# self.input_states = tf.placeholder(
#         tf.float32, shape=[None, 4, board_width, board_height])
# self.input_state = tf.transpose(self.input_states, [0, 2, 3, 1])
# ```
#
# #### Network Layers
#
# ```python
# # 2. Common Networks Layers
# self.conv1 = tf.layers.conv2d(inputs=self.input_state,
#                               filters=32, kernel_size=[3, 3],
#                               padding="same", data_format="channels_last",
#                               activation=tf.nn.relu)
# self.conv2 = tf.layers.conv2d(inputs=self.conv1, filters=64,
#                               kernel_size=[3, 3], padding="same",
#                               data_format="channels_last",
#                               activation=tf.nn.relu)
# self.conv3 = tf.layers.conv2d(inputs=self.conv2, filters=128,
#                               kernel_size=[3, 3], padding="same",
#                               data_format="channels_last",
#                               activation=tf.nn.relu)
# ```
#
# #### Action Networks
#
# ```python
# # 3-1 Action Networks
# self.action_conv = tf.layers.conv2d(inputs=self.conv3, filters=4,
#                                     kernel_size=[1, 1], padding="same",
#                                     data_format="channels_last",
#                                     activation=tf.nn.relu)
# # Flatten the tensor
# self.action_conv_flat = tf.reshape(
#         self.action_conv, [-1, 4 * board_height * board_width])
# # 3-2 Full connected layer, the output is the log probability of moves
# # on each slot on the board
# self.action_fc = tf.layers.dense(inputs=self.action_conv_flat,
#                                  units=board_height * board_width,
#                                  activation=tf.nn.log_softmax)
# ```
#
# #### Evaluation Networks
#
#  ```python
# self.evaluation_conv = tf.layers.conv2d(inputs=self.conv3, filters=2,
#                                         kernel_size=[1, 1],
#                                         padding="same",
#                                         data_format="channels_last",
#                                         activation=tf.nn.relu)
# self.evaluation_conv_flat = tf.reshape(
#         self.evaluation_conv, [-1, 2 * board_height * board_width])
# self.evaluation_fc1 = tf.layers.dense(inputs=self.evaluation_conv_flat,
#                                       units=64, activation=tf.nn.relu)
# # output the score of evaluation on current state
# self.evaluation_fc2 = tf.layers.dense(inputs=self.evaluation_fc1,
#                                       units=1, activation=tf.nn.tanh)
# ```
#
# #### The loss function
#
# ```python
# # 1. Label: the array containing if the game wins or not for each state
# self.labels = tf.placeholder(tf.float32, shape=[None, 1])
# # 2. Predictions: the array containing the evaluation score of each state
# # which is self.evaluation_fc2
# # 3-1. Value Loss function
# self.value_loss = tf.losses.mean_squared_error(self.labels,
#                                                self.evaluation_fc2)
# # 3-2. Policy Loss function
# self.mcts_probs = tf.placeholder(
#         tf.float32, shape=[None, board_height * board_width])
# self.policy_loss = tf.negative(tf.reduce_mean(
#         tf.reduce_sum(tf.multiply(self.mcts_probs, self.action_fc), 1)))
# # 3-3. L2 penalty (regularization)
# l2_penalty_beta = 1e-4
# vars = tf.trainable_variables()
# l2_penalty = l2_penalty_beta * tf.add_n(
#     [tf.nn.l2_loss(v) for v in vars if 'bias' not in v.name.lower()])
# # 3-4 Add up to be the Loss function
# self.loss = self.value_loss + self.policy_loss + l2_penalty
#
# ```
#
# #### The optimizer
#
# ```python
# # Define the optimizer we use for training
# self.learning_rate = tf.placeholder(tf.float32)
# self.optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate).minimize(self.loss)
#
# ```

# %% [markdown]
# ### Training a model
#
# We can also train a new model based on new board dimensions. The best model encountered during training will be stored and can be used to play against.

# %%
import warnings

warnings.filterwarnings("ignore")

from train import TrainPipeline

training_pipeline = TrainPipeline(width=12, height=12, n_in_row=2)
training_pipeline.run()
# Out:
# batch i:1, episode_len:4
# batch i:2, episode_len:3
# batch i:3, episode_len:5
# batch i:4, episode_len:3
# batch i:5, episode_len:3
# batch i:6, episode_len:4
# batch i:7, episode_len:3
# batch i:8, episode_len:3
# batch i:9, episode_len:3
# batch i:10, episode_len:3
# current self-play batch: 10
# num_playouts:1000, win: 5, lose: 5, tie:0
# Found new best!
# batch i:11, episode_len:3
# batch i:12, episode_len:3
# batch i:13, episode_len:3
# batch i:14, episode_len:3
# batch i:15, episode_len:3
# batch i:16, episode_len:4
# batch i:17, episode_len:3
# batch i:18, episode_len:4
# batch i:19, episode_len:3
# batch i:20, episode_len:5
# kl:0.13415,lr_multiplier:0.667,loss:5.691923141479492,entropy:4.891033172607422,explained_var_old:0.007,explained_var_new:-0.217
# current self-play batch: 20
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:21, episode_len:4
# kl:0.04680,lr_multiplier:0.444,loss:5.688155174255371,entropy:4.833124160766602,explained_var_old:-0.185,explained_var_new:0.176
# batch i:22, episode_len:3
# kl:0.02089,lr_multiplier:0.444,loss:5.612888813018799,entropy:4.773968696594238,explained_var_old:0.186,explained_var_new:0.169
# batch i:23, episode_len:3
# kl:0.03973,lr_multiplier:0.444,loss:5.541162490844727,entropy:4.668888568878174,explained_var_old:0.192,explained_var_new:0.190
# batch i:24, episode_len:3
# kl:0.01951,lr_multiplier:0.444,loss:5.4787821769714355,entropy:4.754034042358398,explained_var_old:0.205,explained_var_new:0.221
# batch i:25, episode_len:3
# kl:0.03110,lr_multiplier:0.444,loss:5.312223434448242,entropy:4.567142009735107,explained_var_old:0.231,explained_var_new:0.244
# batch i:26, episode_len:3
# kl:0.02500,lr_multiplier:0.444,loss:5.1755876541137695,entropy:4.481476783752441,explained_var_old:0.222,explained_var_new:0.219
# batch i:27, episode_len:4
# kl:0.03315,lr_multiplier:0.444,loss:5.093638896942139,entropy:4.407495498657227,explained_var_old:0.207,explained_var_new:0.213
# batch i:28, episode_len:3
# kl:0.04334,lr_multiplier:0.296,loss:4.949278354644775,entropy:4.37321138381958,explained_var_old:0.208,explained_var_new:0.220
# batch i:29, episode_len:3
# kl:0.05653,lr_multiplier:0.198,loss:4.665766716003418,entropy:4.046998500823975,explained_var_old:0.202,explained_var_new:0.239
# batch i:30, episode_len:4
# kl:0.01891,lr_multiplier:0.198,loss:4.728361129760742,entropy:4.051994323730469,explained_var_old:0.193,explained_var_new:0.181
# current self-play batch: 30
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:31, episode_len:3
# kl:0.02281,lr_multiplier:0.198,loss:4.612112522125244,entropy:3.9850192070007324,explained_var_old:0.230,explained_var_new:0.290
# batch i:32, episode_len:3
# kl:0.02737,lr_multiplier:0.198,loss:4.447943210601807,entropy:3.8267502784729004,explained_var_old:0.260,explained_var_new:0.257
# batch i:33, episode_len:4
# kl:0.01641,lr_multiplier:0.198,loss:4.3850417137146,entropy:3.684497594833374,explained_var_old:0.216,explained_var_new:0.222
# batch i:34, episode_len:3
# kl:0.02423,lr_multiplier:0.198,loss:4.291857719421387,entropy:3.6355576515197754,explained_var_old:0.263,explained_var_new:0.310
# batch i:35, episode_len:3
# kl:0.01807,lr_multiplier:0.198,loss:4.218377113342285,entropy:3.56304669380188,explained_var_old:0.321,explained_var_new:0.331
# batch i:36, episode_len:3
# kl:0.01478,lr_multiplier:0.198,loss:4.21142053604126,entropy:3.525926351547241,explained_var_old:0.278,explained_var_new:0.295
# batch i:37, episode_len:4
# kl:0.01633,lr_multiplier:0.198,loss:4.111243724822998,entropy:3.4064676761627197,explained_var_old:0.234,explained_var_new:0.267
# batch i:38, episode_len:3
# kl:0.01769,lr_multiplier:0.198,loss:4.073125839233398,entropy:3.4145984649658203,explained_var_old:0.285,explained_var_new:0.309
# batch i:39, episode_len:3
# kl:0.01453,lr_multiplier:0.198,loss:4.15549373626709,entropy:3.5078558921813965,explained_var_old:0.319,explained_var_new:0.331
# batch i:40, episode_len:4
# kl:0.01482,lr_multiplier:0.198,loss:4.157037258148193,entropy:3.5285916328430176,explained_var_old:0.285,explained_var_new:0.322
# current self-play batch: 40
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:41, episode_len:6
# kl:0.01408,lr_multiplier:0.198,loss:4.057615280151367,entropy:3.368602991104126,explained_var_old:0.238,explained_var_new:0.267
# batch i:42, episode_len:3
# kl:0.01315,lr_multiplier:0.198,loss:4.023162364959717,entropy:3.3668570518493652,explained_var_old:0.288,explained_var_new:0.313
# batch i:43, episode_len:5
# kl:0.01594,lr_multiplier:0.198,loss:4.021478652954102,entropy:3.350696563720703,explained_var_old:0.322,explained_var_new:0.355
# batch i:44, episode_len:3
# kl:0.01839,lr_multiplier:0.198,loss:3.8976898193359375,entropy:3.3458924293518066,explained_var_old:0.323,explained_var_new:0.351
# batch i:45, episode_len:3
# kl:0.04370,lr_multiplier:0.132,loss:3.8115389347076416,entropy:3.2688846588134766,explained_var_old:0.358,explained_var_new:0.391
# batch i:46, episode_len:3
# kl:0.01034,lr_multiplier:0.132,loss:3.8747200965881348,entropy:3.2571146488189697,explained_var_old:0.362,explained_var_new:0.378
# batch i:47, episode_len:3
# kl:0.01487,lr_multiplier:0.132,loss:3.862079620361328,entropy:3.2941222190856934,explained_var_old:0.359,explained_var_new:0.395
# batch i:48, episode_len:3
# kl:0.01647,lr_multiplier:0.132,loss:3.977433681488037,entropy:3.372715950012207,explained_var_old:0.323,explained_var_new:0.343
# batch i:49, episode_len:4
# kl:0.01163,lr_multiplier:0.132,loss:3.9485955238342285,entropy:3.3544628620147705,explained_var_old:0.314,explained_var_new:0.341
# batch i:50, episode_len:4
# kl:0.00922,lr_multiplier:0.198,loss:4.134913921356201,entropy:3.457050323486328,explained_var_old:0.286,explained_var_new:0.301
# current self-play batch: 50
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:51, episode_len:3
# kl:0.02017,lr_multiplier:0.198,loss:3.9609744548797607,entropy:3.3607842922210693,explained_var_old:0.331,explained_var_new:0.360
# batch i:52, episode_len:4
# kl:0.02350,lr_multiplier:0.198,loss:3.9984889030456543,entropy:3.322160482406616,explained_var_old:0.281,explained_var_new:0.305
# batch i:53, episode_len:3
# kl:0.02595,lr_multiplier:0.198,loss:3.756988525390625,entropy:3.1177597045898438,explained_var_old:0.283,explained_var_new:0.344
# batch i:54, episode_len:3
# kl:0.02656,lr_multiplier:0.198,loss:3.921804904937744,entropy:3.2893519401550293,explained_var_old:0.299,explained_var_new:0.324
# batch i:55, episode_len:3
# kl:0.03011,lr_multiplier:0.198,loss:3.839979410171509,entropy:3.221137046813965,explained_var_old:0.294,explained_var_new:0.349
# batch i:56, episode_len:3
# kl:0.01750,lr_multiplier:0.198,loss:3.917382001876831,entropy:3.2738070487976074,explained_var_old:0.351,explained_var_new:0.367
# batch i:57, episode_len:4
# kl:0.02165,lr_multiplier:0.198,loss:3.959664821624756,entropy:3.306626558303833,explained_var_old:0.270,explained_var_new:0.306
# batch i:58, episode_len:3
# kl:0.02752,lr_multiplier:0.198,loss:3.970551013946533,entropy:3.261390447616577,explained_var_old:0.272,explained_var_new:0.302
# batch i:59, episode_len:4
# kl:0.02363,lr_multiplier:0.198,loss:3.8495020866394043,entropy:3.2013282775878906,explained_var_old:0.331,explained_var_new:0.350
# batch i:60, episode_len:3
# kl:0.01659,lr_multiplier:0.198,loss:3.713468551635742,entropy:3.1804146766662598,explained_var_old:0.329,explained_var_new:0.358
# current self-play batch: 60
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:61, episode_len:3
# kl:0.01912,lr_multiplier:0.198,loss:3.7507286071777344,entropy:3.1633095741271973,explained_var_old:0.375,explained_var_new:0.398
# batch i:62, episode_len:3
# kl:0.02729,lr_multiplier:0.198,loss:3.7377474308013916,entropy:3.138918399810791,explained_var_old:0.356,explained_var_new:0.379
# batch i:63, episode_len:3
# kl:0.01166,lr_multiplier:0.198,loss:3.755462408065796,entropy:3.146390676498413,explained_var_old:0.327,explained_var_new:0.367
# batch i:64, episode_len:3
# kl:0.02654,lr_multiplier:0.198,loss:3.632650136947632,entropy:3.1026272773742676,explained_var_old:0.421,explained_var_new:0.448
# batch i:65, episode_len:3
# kl:0.01915,lr_multiplier:0.198,loss:3.8339056968688965,entropy:3.2213993072509766,explained_var_old:0.362,explained_var_new:0.383
# batch i:66, episode_len:6
# kl:0.02807,lr_multiplier:0.198,loss:3.798948287963867,entropy:3.201463222503662,explained_var_old:0.348,explained_var_new:0.383
# batch i:67, episode_len:3
# kl:0.01805,lr_multiplier:0.198,loss:3.597776412963867,entropy:2.9974286556243896,explained_var_old:0.348,explained_var_new:0.385
# batch i:68, episode_len:4
# kl:0.01819,lr_multiplier:0.198,loss:3.86858868598938,entropy:3.190768241882324,explained_var_old:0.316,explained_var_new:0.340
# batch i:69, episode_len:3
# kl:0.01691,lr_multiplier:0.198,loss:3.6848058700561523,entropy:3.1142094135284424,explained_var_old:0.412,explained_var_new:0.443
# batch i:70, episode_len:5
# kl:0.01711,lr_multiplier:0.198,loss:3.779334306716919,entropy:3.1923561096191406,explained_var_old:0.336,explained_var_new:0.366
# current self-play batch: 70
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:71, episode_len:3
# kl:0.02732,lr_multiplier:0.198,loss:3.623441219329834,entropy:2.9742813110351562,explained_var_old:0.365,explained_var_new:0.395
# batch i:72, episode_len:3
# kl:0.01894,lr_multiplier:0.198,loss:3.5927581787109375,entropy:3.039886951446533,explained_var_old:0.380,explained_var_new:0.408
# batch i:73, episode_len:4
# kl:0.02204,lr_multiplier:0.198,loss:3.521545648574829,entropy:2.9073829650878906,explained_var_old:0.334,explained_var_new:0.365
# batch i:74, episode_len:3
# kl:0.01196,lr_multiplier:0.198,loss:3.6180062294006348,entropy:3.0455260276794434,explained_var_old:0.356,explained_var_new:0.400
# batch i:75, episode_len:3
# kl:0.01604,lr_multiplier:0.198,loss:3.5744450092315674,entropy:2.9993813037872314,explained_var_old:0.384,explained_var_new:0.409
# batch i:76, episode_len:3
# kl:0.01340,lr_multiplier:0.198,loss:3.6169662475585938,entropy:3.0951688289642334,explained_var_old:0.379,explained_var_new:0.407
# batch i:77, episode_len:3
# kl:0.01779,lr_multiplier:0.198,loss:3.5267038345336914,entropy:2.935204267501831,explained_var_old:0.427,explained_var_new:0.470
# batch i:78, episode_len:3
# kl:0.01859,lr_multiplier:0.198,loss:3.634539842605591,entropy:3.0234224796295166,explained_var_old:0.372,explained_var_new:0.403
# batch i:79, episode_len:3
# kl:0.03360,lr_multiplier:0.198,loss:3.472257375717163,entropy:2.915858268737793,explained_var_old:0.430,explained_var_new:0.468
# batch i:80, episode_len:3
# kl:0.01757,lr_multiplier:0.198,loss:3.6982972621917725,entropy:3.103210687637329,explained_var_old:0.389,explained_var_new:0.417
# current self-play batch: 80
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:81, episode_len:3
# kl:0.02045,lr_multiplier:0.198,loss:3.338022470474243,entropy:2.8329129219055176,explained_var_old:0.431,explained_var_new:0.459
# batch i:82, episode_len:3
# kl:0.01938,lr_multiplier:0.198,loss:3.4564619064331055,entropy:2.9572739601135254,explained_var_old:0.495,explained_var_new:0.525
# batch i:83, episode_len:3
# kl:0.02013,lr_multiplier:0.198,loss:3.504920244216919,entropy:3.0459742546081543,explained_var_old:0.531,explained_var_new:0.559
# batch i:84, episode_len:3
# kl:0.02837,lr_multiplier:0.198,loss:3.635262966156006,entropy:3.107060432434082,explained_var_old:0.362,explained_var_new:0.409
# batch i:85, episode_len:3
# kl:0.02332,lr_multiplier:0.198,loss:3.4964566230773926,entropy:3.03786301612854,explained_var_old:0.463,explained_var_new:0.502
# batch i:86, episode_len:3
# kl:0.02141,lr_multiplier:0.198,loss:3.477503776550293,entropy:3.060114622116089,explained_var_old:0.503,explained_var_new:0.528
# batch i:87, episode_len:3
# kl:0.02114,lr_multiplier:0.198,loss:3.46252703666687,entropy:2.917019844055176,explained_var_old:0.385,explained_var_new:0.404
# batch i:88, episode_len:4
# kl:0.02363,lr_multiplier:0.198,loss:3.3877179622650146,entropy:2.8144266605377197,explained_var_old:0.368,explained_var_new:0.410
# batch i:89, episode_len:3
# kl:0.01982,lr_multiplier:0.198,loss:3.394524574279785,entropy:2.90472674369812,explained_var_old:0.482,explained_var_new:0.542
# batch i:90, episode_len:3
# kl:0.02047,lr_multiplier:0.198,loss:3.461397886276245,entropy:3.030646324157715,explained_var_old:0.504,explained_var_new:0.525
# current self-play batch: 90
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:91, episode_len:3
# kl:0.03388,lr_multiplier:0.198,loss:3.459116220474243,entropy:2.93218731880188,explained_var_old:0.415,explained_var_new:0.447
# batch i:92, episode_len:3
# kl:0.01660,lr_multiplier:0.198,loss:3.4777374267578125,entropy:2.9121272563934326,explained_var_old:0.369,explained_var_new:0.394
# batch i:93, episode_len:3
# kl:0.01944,lr_multiplier:0.198,loss:3.482701301574707,entropy:2.9555704593658447,explained_var_old:0.439,explained_var_new:0.499
# batch i:94, episode_len:3
# kl:0.02273,lr_multiplier:0.198,loss:3.616440534591675,entropy:3.03080677986145,explained_var_old:0.429,explained_var_new:0.445
# batch i:95, episode_len:3
# kl:0.01293,lr_multiplier:0.198,loss:3.4873335361480713,entropy:2.9910058975219727,explained_var_old:0.416,explained_var_new:0.452
# batch i:96, episode_len:3
# kl:0.02090,lr_multiplier:0.198,loss:3.4988367557525635,entropy:2.9791617393493652,explained_var_old:0.430,explained_var_new:0.462
# batch i:97, episode_len:4
# kl:0.01499,lr_multiplier:0.198,loss:3.384315013885498,entropy:2.89148211479187,explained_var_old:0.468,explained_var_new:0.494
# batch i:98, episode_len:3
# kl:0.01281,lr_multiplier:0.198,loss:3.2981932163238525,entropy:2.818859100341797,explained_var_old:0.451,explained_var_new:0.488
# batch i:99, episode_len:3
# kl:0.01203,lr_multiplier:0.198,loss:3.477590322494507,entropy:3.0123727321624756,explained_var_old:0.479,explained_var_new:0.502
# batch i:100, episode_len:3
# kl:0.02243,lr_multiplier:0.198,loss:3.5458779335021973,entropy:3.0022640228271484,explained_var_old:0.459,explained_var_new:0.503
# current self-play batch: 100
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:101, episode_len:3
# kl:0.01584,lr_multiplier:0.198,loss:3.442958116531372,entropy:2.9574785232543945,explained_var_old:0.449,explained_var_new:0.474
# batch i:102, episode_len:3
# kl:0.01490,lr_multiplier:0.198,loss:3.4762208461761475,entropy:3.0108931064605713,explained_var_old:0.478,explained_var_new:0.514
# batch i:103, episode_len:5
# kl:0.01194,lr_multiplier:0.198,loss:3.4337148666381836,entropy:2.9409656524658203,explained_var_old:0.462,explained_var_new:0.483
# batch i:104, episode_len:3
# kl:0.01032,lr_multiplier:0.198,loss:3.313288927078247,entropy:2.8450820446014404,explained_var_old:0.526,explained_var_new:0.552
# batch i:105, episode_len:3
# kl:0.00977,lr_multiplier:0.296,loss:3.358715295791626,entropy:2.9141547679901123,explained_var_old:0.538,explained_var_new:0.553
# batch i:106, episode_len:3
# kl:0.02354,lr_multiplier:0.296,loss:3.368419647216797,entropy:2.8969852924346924,explained_var_old:0.422,explained_var_new:0.458
# batch i:107, episode_len:3
# kl:0.02080,lr_multiplier:0.296,loss:3.3382315635681152,entropy:2.715614080429077,explained_var_old:0.382,explained_var_new:0.421
# batch i:108, episode_len:4
# kl:0.01900,lr_multiplier:0.296,loss:3.4119632244110107,entropy:2.869286298751831,explained_var_old:0.428,explained_var_new:0.463
# batch i:109, episode_len:4
# kl:0.01523,lr_multiplier:0.296,loss:3.3724071979522705,entropy:2.8528189659118652,explained_var_old:0.418,explained_var_new:0.451
# batch i:110, episode_len:3
# kl:0.01630,lr_multiplier:0.296,loss:3.3277769088745117,entropy:2.875004768371582,explained_var_old:0.510,explained_var_new:0.558
# current self-play batch: 110
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:111, episode_len:3
# kl:0.01684,lr_multiplier:0.296,loss:3.316201686859131,entropy:2.8206779956817627,explained_var_old:0.442,explained_var_new:0.465
# batch i:112, episode_len:3
# kl:0.02255,lr_multiplier:0.296,loss:3.270852565765381,entropy:2.778377056121826,explained_var_old:0.529,explained_var_new:0.570
# batch i:113, episode_len:3
# kl:0.02751,lr_multiplier:0.296,loss:3.4255497455596924,entropy:2.8323910236358643,explained_var_old:0.393,explained_var_new:0.437
# batch i:114, episode_len:3
# kl:0.02078,lr_multiplier:0.296,loss:3.402832269668579,entropy:2.8291664123535156,explained_var_old:0.434,explained_var_new:0.478
# batch i:115, episode_len:4
# kl:0.01626,lr_multiplier:0.296,loss:3.346877098083496,entropy:2.763071298599243,explained_var_old:0.401,explained_var_new:0.451
# batch i:116, episode_len:3
# kl:0.02225,lr_multiplier:0.296,loss:3.486985445022583,entropy:2.9755256175994873,explained_var_old:0.397,explained_var_new:0.428
# batch i:117, episode_len:4
# kl:0.02884,lr_multiplier:0.296,loss:3.3636226654052734,entropy:2.7902896404266357,explained_var_old:0.445,explained_var_new:0.500
# batch i:118, episode_len:3
# kl:0.03760,lr_multiplier:0.296,loss:3.4709532260894775,entropy:2.874817371368408,explained_var_old:0.354,explained_var_new:0.394
# batch i:119, episode_len:3
# kl:0.03174,lr_multiplier:0.296,loss:3.493037223815918,entropy:2.9214529991149902,explained_var_old:0.380,explained_var_new:0.415
# batch i:120, episode_len:4
# kl:0.03361,lr_multiplier:0.296,loss:3.3912296295166016,entropy:2.838310956954956,explained_var_old:0.411,explained_var_new:0.465
# current self-play batch: 120
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:121, episode_len:3
# kl:0.02077,lr_multiplier:0.296,loss:3.2748749256134033,entropy:2.8035926818847656,explained_var_old:0.461,explained_var_new:0.511
# batch i:122, episode_len:3
# kl:0.01857,lr_multiplier:0.296,loss:3.402916193008423,entropy:2.87202787399292,explained_var_old:0.419,explained_var_new:0.455
# batch i:123, episode_len:3
# kl:0.01654,lr_multiplier:0.296,loss:3.3007912635803223,entropy:2.8124592304229736,explained_var_old:0.420,explained_var_new:0.479
# batch i:124, episode_len:4
# kl:0.01834,lr_multiplier:0.296,loss:3.480276107788086,entropy:2.846081256866455,explained_var_old:0.307,explained_var_new:0.344
# batch i:125, episode_len:3
# kl:0.01273,lr_multiplier:0.296,loss:3.4146363735198975,entropy:2.8878486156463623,explained_var_old:0.407,explained_var_new:0.455
# batch i:126, episode_len:3
# kl:0.01648,lr_multiplier:0.296,loss:3.5478596687316895,entropy:2.935106039047241,explained_var_old:0.374,explained_var_new:0.404
# batch i:127, episode_len:3
# kl:0.01634,lr_multiplier:0.296,loss:3.431234836578369,entropy:2.9063000679016113,explained_var_old:0.342,explained_var_new:0.393
# batch i:128, episode_len:3
# kl:0.01773,lr_multiplier:0.296,loss:3.4535439014434814,entropy:2.8190996646881104,explained_var_old:0.423,explained_var_new:0.490
# batch i:129, episode_len:3
# kl:0.03611,lr_multiplier:0.296,loss:3.2174572944641113,entropy:2.7764971256256104,explained_var_old:0.445,explained_var_new:0.499
# batch i:130, episode_len:3
# kl:0.03428,lr_multiplier:0.296,loss:3.5419087409973145,entropy:2.9743804931640625,explained_var_old:0.398,explained_var_new:0.422
# current self-play batch: 130
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:131, episode_len:3
# kl:0.03096,lr_multiplier:0.296,loss:3.5032734870910645,entropy:2.983508586883545,explained_var_old:0.422,explained_var_new:0.463
# batch i:132, episode_len:3
# kl:0.02299,lr_multiplier:0.296,loss:3.4224672317504883,entropy:2.9356794357299805,explained_var_old:0.433,explained_var_new:0.467
# batch i:133, episode_len:4
# kl:0.03164,lr_multiplier:0.296,loss:3.3485236167907715,entropy:2.8119149208068848,explained_var_old:0.399,explained_var_new:0.456
# batch i:134, episode_len:3
# kl:0.03508,lr_multiplier:0.296,loss:3.4453699588775635,entropy:2.9623987674713135,explained_var_old:0.432,explained_var_new:0.472
# batch i:135, episode_len:3
# kl:0.02809,lr_multiplier:0.296,loss:3.3330399990081787,entropy:2.774193286895752,explained_var_old:0.414,explained_var_new:0.446
# batch i:136, episode_len:4
# kl:0.02002,lr_multiplier:0.296,loss:3.199577569961548,entropy:2.6956098079681396,explained_var_old:0.413,explained_var_new:0.450
# batch i:137, episode_len:3
# kl:0.01566,lr_multiplier:0.296,loss:3.547191619873047,entropy:2.9759654998779297,explained_var_old:0.353,explained_var_new:0.397
# batch i:138, episode_len:3
# kl:0.01703,lr_multiplier:0.296,loss:3.363257884979248,entropy:2.733408212661743,explained_var_old:0.314,explained_var_new:0.346
# batch i:139, episode_len:3
# kl:0.01864,lr_multiplier:0.296,loss:3.3584084510803223,entropy:2.85927414894104,explained_var_old:0.440,explained_var_new:0.494
# batch i:140, episode_len:3
# kl:0.02867,lr_multiplier:0.296,loss:3.417731285095215,entropy:2.7742621898651123,explained_var_old:0.345,explained_var_new:0.373
# current self-play batch: 140
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:141, episode_len:3
# kl:0.05318,lr_multiplier:0.198,loss:3.29602313041687,entropy:2.7344813346862793,explained_var_old:0.409,explained_var_new:0.433
# batch i:142, episode_len:3
# kl:0.01238,lr_multiplier:0.198,loss:3.229353427886963,entropy:2.706507682800293,explained_var_old:0.449,explained_var_new:0.478
# batch i:143, episode_len:3
# kl:0.00706,lr_multiplier:0.296,loss:3.272399663925171,entropy:2.7066597938537598,explained_var_old:0.396,explained_var_new:0.419
# batch i:144, episode_len:3
# kl:0.01413,lr_multiplier:0.296,loss:3.3277573585510254,entropy:2.793748378753662,explained_var_old:0.387,explained_var_new:0.423
# batch i:145, episode_len:4
# kl:0.01471,lr_multiplier:0.296,loss:3.289677858352661,entropy:2.6736159324645996,explained_var_old:0.371,explained_var_new:0.405
# batch i:146, episode_len:4
# kl:0.01094,lr_multiplier:0.296,loss:3.310925245285034,entropy:2.7592272758483887,explained_var_old:0.426,explained_var_new:0.454
# batch i:147, episode_len:3
# kl:0.01860,lr_multiplier:0.296,loss:3.3232226371765137,entropy:2.8235490322113037,explained_var_old:0.371,explained_var_new:0.426
# batch i:148, episode_len:3
# kl:0.01811,lr_multiplier:0.296,loss:3.2880451679229736,entropy:2.720837116241455,explained_var_old:0.416,explained_var_new:0.462
# batch i:149, episode_len:3
# kl:0.01343,lr_multiplier:0.296,loss:3.5603342056274414,entropy:2.957566261291504,explained_var_old:0.328,explained_var_new:0.386
# batch i:150, episode_len:3
# kl:0.01284,lr_multiplier:0.296,loss:3.3074119091033936,entropy:2.778944969177246,explained_var_old:0.444,explained_var_new:0.480
# current self-play batch: 150
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:151, episode_len:3
# kl:0.01479,lr_multiplier:0.296,loss:3.3921844959259033,entropy:2.9129555225372314,explained_var_old:0.429,explained_var_new:0.459
# batch i:152, episode_len:3
# kl:0.02197,lr_multiplier:0.296,loss:3.355010986328125,entropy:2.7219088077545166,explained_var_old:0.385,explained_var_new:0.433
# batch i:153, episode_len:4
# kl:0.02233,lr_multiplier:0.296,loss:3.424398422241211,entropy:2.9161479473114014,explained_var_old:0.404,explained_var_new:0.434
# batch i:154, episode_len:3
# kl:0.01606,lr_multiplier:0.296,loss:3.390003204345703,entropy:2.866564989089966,explained_var_old:0.449,explained_var_new:0.480
# batch i:155, episode_len:3
# kl:0.01091,lr_multiplier:0.296,loss:3.50980281829834,entropy:2.96366810798645,explained_var_old:0.372,explained_var_new:0.413
# batch i:156, episode_len:3
# kl:0.01481,lr_multiplier:0.296,loss:3.4085021018981934,entropy:2.924041748046875,explained_var_old:0.485,explained_var_new:0.520
# batch i:157, episode_len:3
# kl:0.01979,lr_multiplier:0.296,loss:3.4009900093078613,entropy:2.893096685409546,explained_var_old:0.488,explained_var_new:0.510
# batch i:158, episode_len:4
# kl:0.01592,lr_multiplier:0.296,loss:3.145512104034424,entropy:2.6288318634033203,explained_var_old:0.417,explained_var_new:0.456
# batch i:159, episode_len:3
# kl:0.01233,lr_multiplier:0.296,loss:3.4814507961273193,entropy:3.010378837585449,explained_var_old:0.349,explained_var_new:0.394
# batch i:160, episode_len:3
# kl:0.02522,lr_multiplier:0.296,loss:3.201308012008667,entropy:2.530524253845215,explained_var_old:0.444,explained_var_new:0.480
# current self-play batch: 160
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:161, episode_len:3
# kl:0.02923,lr_multiplier:0.296,loss:3.3877038955688477,entropy:2.9635465145111084,explained_var_old:0.467,explained_var_new:0.516
# batch i:162, episode_len:4
# kl:0.04047,lr_multiplier:0.198,loss:3.3775250911712646,entropy:2.817905902862549,explained_var_old:0.417,explained_var_new:0.444
# batch i:163, episode_len:3
# kl:0.05556,lr_multiplier:0.132,loss:3.4408023357391357,entropy:2.9333884716033936,explained_var_old:0.361,explained_var_new:0.395
# batch i:164, episode_len:3
# kl:0.01305,lr_multiplier:0.132,loss:3.3681492805480957,entropy:2.8640947341918945,explained_var_old:0.442,explained_var_new:0.457
# batch i:165, episode_len:3
# kl:0.01422,lr_multiplier:0.132,loss:3.3613266944885254,entropy:2.759612560272217,explained_var_old:0.466,explained_var_new:0.477
# batch i:166, episode_len:3
# kl:0.01628,lr_multiplier:0.132,loss:3.3187801837921143,entropy:2.766446828842163,explained_var_old:0.441,explained_var_new:0.459
# batch i:167, episode_len:3
# kl:0.00460,lr_multiplier:0.198,loss:3.254049062728882,entropy:2.843461275100708,explained_var_old:0.515,explained_var_new:0.547
# batch i:168, episode_len:3
# kl:0.01086,lr_multiplier:0.198,loss:3.125908613204956,entropy:2.5975546836853027,explained_var_old:0.417,explained_var_new:0.447
# batch i:169, episode_len:3
# kl:0.02356,lr_multiplier:0.198,loss:3.335789918899536,entropy:2.773693323135376,explained_var_old:0.377,explained_var_new:0.400
# batch i:170, episode_len:5
# kl:0.03045,lr_multiplier:0.198,loss:3.2611777782440186,entropy:2.66194748878479,explained_var_old:0.419,explained_var_new:0.460
# current self-play batch: 170
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:171, episode_len:3
# kl:0.01261,lr_multiplier:0.198,loss:3.3285701274871826,entropy:2.7733826637268066,explained_var_old:0.428,explained_var_new:0.459
# batch i:172, episode_len:3
# kl:0.00984,lr_multiplier:0.296,loss:3.419485330581665,entropy:2.910125732421875,explained_var_old:0.386,explained_var_new:0.420
# batch i:173, episode_len:3
# kl:0.01270,lr_multiplier:0.296,loss:3.284675121307373,entropy:2.7349047660827637,explained_var_old:0.433,explained_var_new:0.464
# batch i:174, episode_len:3
# kl:0.01512,lr_multiplier:0.296,loss:3.2261087894439697,entropy:2.732067346572876,explained_var_old:0.408,explained_var_new:0.450
# batch i:175, episode_len:3
# kl:0.01642,lr_multiplier:0.296,loss:3.2051608562469482,entropy:2.683195114135742,explained_var_old:0.459,explained_var_new:0.482
# batch i:176, episode_len:3
# kl:0.01744,lr_multiplier:0.296,loss:3.3036367893218994,entropy:2.759946823120117,explained_var_old:0.464,explained_var_new:0.497
# batch i:177, episode_len:4
# kl:0.01371,lr_multiplier:0.296,loss:3.274685859680176,entropy:2.717047691345215,explained_var_old:0.350,explained_var_new:0.388
# batch i:178, episode_len:3
# kl:0.01617,lr_multiplier:0.296,loss:3.31315279006958,entropy:2.8290457725524902,explained_var_old:0.531,explained_var_new:0.559
# batch i:179, episode_len:3
# kl:0.02413,lr_multiplier:0.296,loss:3.3837854862213135,entropy:2.9202017784118652,explained_var_old:0.424,explained_var_new:0.469
# batch i:180, episode_len:3
# kl:0.03961,lr_multiplier:0.296,loss:3.2731528282165527,entropy:2.6908140182495117,explained_var_old:0.456,explained_var_new:0.499
# current self-play batch: 180
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:181, episode_len:3
# kl:0.04186,lr_multiplier:0.198,loss:3.3125863075256348,entropy:2.902906894683838,explained_var_old:0.437,explained_var_new:0.477
# batch i:182, episode_len:3
# kl:0.01229,lr_multiplier:0.198,loss:3.301816463470459,entropy:2.7532577514648438,explained_var_old:0.429,explained_var_new:0.467
# batch i:183, episode_len:3
# kl:0.01258,lr_multiplier:0.198,loss:3.22711181640625,entropy:2.683058261871338,explained_var_old:0.445,explained_var_new:0.468
# batch i:184, episode_len:3
# kl:0.01082,lr_multiplier:0.198,loss:3.1590194702148438,entropy:2.727724313735962,explained_var_old:0.489,explained_var_new:0.517
# batch i:185, episode_len:3
# kl:0.01058,lr_multiplier:0.198,loss:3.0596516132354736,entropy:2.5618481636047363,explained_var_old:0.442,explained_var_new:0.473
# batch i:186, episode_len:4
# kl:0.01311,lr_multiplier:0.198,loss:3.3766043186187744,entropy:2.834482192993164,explained_var_old:0.451,explained_var_new:0.468
# batch i:187, episode_len:4
# kl:0.01536,lr_multiplier:0.198,loss:3.4472951889038086,entropy:2.898749828338623,explained_var_old:0.471,explained_var_new:0.485
# batch i:188, episode_len:4
# kl:0.00770,lr_multiplier:0.296,loss:3.253758668899536,entropy:2.7557616233825684,explained_var_old:0.452,explained_var_new:0.490
# batch i:189, episode_len:3
# kl:0.01268,lr_multiplier:0.296,loss:3.362457036972046,entropy:2.884383201599121,explained_var_old:0.468,explained_var_new:0.494
# batch i:190, episode_len:3
# kl:0.00728,lr_multiplier:0.444,loss:3.3019049167633057,entropy:2.685983896255493,explained_var_old:0.332,explained_var_new:0.377
# current self-play batch: 190
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:191, episode_len:4
# kl:0.01390,lr_multiplier:0.444,loss:3.17895245552063,entropy:2.631331205368042,explained_var_old:0.423,explained_var_new:0.460
# batch i:192, episode_len:4
# kl:0.01266,lr_multiplier:0.444,loss:3.3550448417663574,entropy:2.7528252601623535,explained_var_old:0.369,explained_var_new:0.404
# batch i:193, episode_len:3
# kl:0.02917,lr_multiplier:0.444,loss:3.343668222427368,entropy:2.73441219329834,explained_var_old:0.371,explained_var_new:0.428
# batch i:194, episode_len:3
# kl:0.02870,lr_multiplier:0.444,loss:3.3155696392059326,entropy:2.862199306488037,explained_var_old:0.414,explained_var_new:0.501
# batch i:195, episode_len:3
# kl:0.02325,lr_multiplier:0.444,loss:3.2590723037719727,entropy:2.728919506072998,explained_var_old:0.411,explained_var_new:0.442
# batch i:196, episode_len:3
# kl:0.02439,lr_multiplier:0.444,loss:3.2655155658721924,entropy:2.7155728340148926,explained_var_old:0.366,explained_var_new:0.412
# batch i:197, episode_len:4
# kl:0.02785,lr_multiplier:0.444,loss:3.3460118770599365,entropy:2.739201545715332,explained_var_old:0.382,explained_var_new:0.420
# batch i:198, episode_len:4
# kl:0.03758,lr_multiplier:0.444,loss:3.390685796737671,entropy:2.7825064659118652,explained_var_old:0.372,explained_var_new:0.422
# batch i:199, episode_len:4
# kl:0.03541,lr_multiplier:0.444,loss:3.349403142929077,entropy:2.822784423828125,explained_var_old:0.365,explained_var_new:0.429
# batch i:200, episode_len:3
# kl:0.03122,lr_multiplier:0.444,loss:3.18859601020813,entropy:2.644639015197754,explained_var_old:0.400,explained_var_new:0.437
# current self-play batch: 200
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:201, episode_len:3
# kl:0.02297,lr_multiplier:0.444,loss:3.2321348190307617,entropy:2.7763726711273193,explained_var_old:0.489,explained_var_new:0.536
# batch i:202, episode_len:3
# kl:0.02935,lr_multiplier:0.444,loss:3.253506660461426,entropy:2.6102516651153564,explained_var_old:0.371,explained_var_new:0.411
# batch i:203, episode_len:4
# kl:0.03145,lr_multiplier:0.444,loss:3.288983106613159,entropy:2.7380573749542236,explained_var_old:0.333,explained_var_new:0.376
# batch i:204, episode_len:5
# kl:0.01710,lr_multiplier:0.444,loss:3.215425491333008,entropy:2.665069580078125,explained_var_old:0.384,explained_var_new:0.432
# batch i:205, episode_len:4
# kl:0.03592,lr_multiplier:0.444,loss:3.2710349559783936,entropy:2.7002010345458984,explained_var_old:0.393,explained_var_new:0.450
# batch i:206, episode_len:3
# kl:0.03813,lr_multiplier:0.444,loss:3.2913243770599365,entropy:2.6862564086914062,explained_var_old:0.303,explained_var_new:0.381
# batch i:207, episode_len:4
# kl:0.03362,lr_multiplier:0.444,loss:3.2195520401000977,entropy:2.6034021377563477,explained_var_old:0.347,explained_var_new:0.389
# batch i:208, episode_len:3
# kl:0.02576,lr_multiplier:0.444,loss:3.324568510055542,entropy:2.757943630218506,explained_var_old:0.411,explained_var_new:0.465
# batch i:209, episode_len:5
# kl:0.03364,lr_multiplier:0.444,loss:3.54642915725708,entropy:2.9260294437408447,explained_var_old:0.314,explained_var_new:0.369
# batch i:210, episode_len:3
# kl:0.03037,lr_multiplier:0.444,loss:3.310053825378418,entropy:2.6857481002807617,explained_var_old:0.354,explained_var_new:0.407
# current self-play batch: 210
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:211, episode_len:3
# kl:0.02364,lr_multiplier:0.444,loss:3.2491681575775146,entropy:2.68699312210083,explained_var_old:0.383,explained_var_new:0.431
# batch i:212, episode_len:3
# kl:0.03176,lr_multiplier:0.444,loss:3.3118391036987305,entropy:2.7723751068115234,explained_var_old:0.391,explained_var_new:0.414
# batch i:213, episode_len:3
# kl:0.03607,lr_multiplier:0.444,loss:3.11960506439209,entropy:2.5750694274902344,explained_var_old:0.404,explained_var_new:0.447
# batch i:214, episode_len:3
# kl:0.05116,lr_multiplier:0.296,loss:3.02433705329895,entropy:2.488241672515869,explained_var_old:0.485,explained_var_new:0.535
# batch i:215, episode_len:3
# kl:0.02851,lr_multiplier:0.296,loss:3.4059219360351562,entropy:2.795564889907837,explained_var_old:0.355,explained_var_new:0.392
# batch i:216, episode_len:3
# kl:0.02560,lr_multiplier:0.296,loss:3.2680113315582275,entropy:2.77990460395813,explained_var_old:0.444,explained_var_new:0.478
# batch i:217, episode_len:3
# kl:0.02272,lr_multiplier:0.296,loss:3.3281962871551514,entropy:2.8280458450317383,explained_var_old:0.381,explained_var_new:0.439
# batch i:218, episode_len:3
# kl:0.02541,lr_multiplier:0.296,loss:3.331688642501831,entropy:2.711716651916504,explained_var_old:0.434,explained_var_new:0.452
# batch i:219, episode_len:3
# kl:0.01574,lr_multiplier:0.296,loss:3.1950795650482178,entropy:2.669703722000122,explained_var_old:0.389,explained_var_new:0.454
# batch i:220, episode_len:4
# kl:0.01722,lr_multiplier:0.296,loss:3.2136077880859375,entropy:2.6623759269714355,explained_var_old:0.411,explained_var_new:0.436
# current self-play batch: 220
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:221, episode_len:3
# kl:0.01697,lr_multiplier:0.296,loss:3.0304195880889893,entropy:2.554610252380371,explained_var_old:0.435,explained_var_new:0.463
# batch i:222, episode_len:3
# kl:0.01706,lr_multiplier:0.296,loss:3.113353967666626,entropy:2.6382288932800293,explained_var_old:0.449,explained_var_new:0.483
# batch i:223, episode_len:3
# kl:0.01166,lr_multiplier:0.296,loss:3.269603967666626,entropy:2.651594638824463,explained_var_old:0.383,explained_var_new:0.416
# batch i:224, episode_len:3
# kl:0.01062,lr_multiplier:0.296,loss:3.138566493988037,entropy:2.641179323196411,explained_var_old:0.471,explained_var_new:0.506
# batch i:225, episode_len:3
# kl:0.01319,lr_multiplier:0.296,loss:3.2606301307678223,entropy:2.679539918899536,explained_var_old:0.391,explained_var_new:0.428
# batch i:226, episode_len:3
# kl:0.01807,lr_multiplier:0.296,loss:3.3406174182891846,entropy:2.8773930072784424,explained_var_old:0.396,explained_var_new:0.443
# batch i:227, episode_len:3
# kl:0.01880,lr_multiplier:0.296,loss:3.3209242820739746,entropy:2.6557090282440186,explained_var_old:0.362,explained_var_new:0.394
# batch i:228, episode_len:3
# kl:0.00994,lr_multiplier:0.444,loss:3.233295202255249,entropy:2.7880630493164062,explained_var_old:0.477,explained_var_new:0.517
# batch i:229, episode_len:3
# kl:0.01781,lr_multiplier:0.444,loss:3.205137252807617,entropy:2.650251865386963,explained_var_old:0.374,explained_var_new:0.433
# batch i:230, episode_len:3
# kl:0.02158,lr_multiplier:0.444,loss:3.1576192378997803,entropy:2.6207311153411865,explained_var_old:0.423,explained_var_new:0.477
# current self-play batch: 230
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:231, episode_len:4
# kl:0.02978,lr_multiplier:0.444,loss:3.2283775806427,entropy:2.6713883876800537,explained_var_old:0.374,explained_var_new:0.420
# batch i:232, episode_len:6
# kl:0.01819,lr_multiplier:0.444,loss:3.2968709468841553,entropy:2.7558822631835938,explained_var_old:0.412,explained_var_new:0.483
# batch i:233, episode_len:4
# kl:0.02138,lr_multiplier:0.444,loss:3.39125919342041,entropy:2.7164244651794434,explained_var_old:0.279,explained_var_new:0.355
# batch i:234, episode_len:4
# kl:0.03184,lr_multiplier:0.444,loss:3.3798704147338867,entropy:2.8695971965789795,explained_var_old:0.379,explained_var_new:0.416
# batch i:235, episode_len:3
# kl:0.03538,lr_multiplier:0.444,loss:3.270695686340332,entropy:2.6497750282287598,explained_var_old:0.346,explained_var_new:0.410
# batch i:236, episode_len:5
# kl:0.03599,lr_multiplier:0.444,loss:3.1969847679138184,entropy:2.5945425033569336,explained_var_old:0.390,explained_var_new:0.438
# batch i:237, episode_len:4
# kl:0.04740,lr_multiplier:0.296,loss:3.2985000610351562,entropy:2.7830357551574707,explained_var_old:0.374,explained_var_new:0.408
# batch i:238, episode_len:3
# kl:0.01460,lr_multiplier:0.296,loss:3.136284112930298,entropy:2.580068588256836,explained_var_old:0.398,explained_var_new:0.429
# batch i:239, episode_len:3
# kl:0.02177,lr_multiplier:0.296,loss:3.241095542907715,entropy:2.738457679748535,explained_var_old:0.412,explained_var_new:0.435
# batch i:240, episode_len:3
# kl:0.02307,lr_multiplier:0.296,loss:3.1615660190582275,entropy:2.615480899810791,explained_var_old:0.473,explained_var_new:0.508
# current self-play batch: 240
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:241, episode_len:3
# kl:0.01904,lr_multiplier:0.296,loss:3.289990186691284,entropy:2.839294195175171,explained_var_old:0.406,explained_var_new:0.442
# batch i:242, episode_len:4
# kl:0.02617,lr_multiplier:0.296,loss:3.2121665477752686,entropy:2.5493171215057373,explained_var_old:0.377,explained_var_new:0.423
# batch i:243, episode_len:4
# kl:0.02716,lr_multiplier:0.296,loss:3.25433087348938,entropy:2.787038564682007,explained_var_old:0.350,explained_var_new:0.385
# batch i:244, episode_len:3
# kl:0.03883,lr_multiplier:0.296,loss:3.405946969985962,entropy:2.6803410053253174,explained_var_old:0.293,explained_var_new:0.342
# batch i:245, episode_len:3
# kl:0.02149,lr_multiplier:0.296,loss:3.232067108154297,entropy:2.6486520767211914,explained_var_old:0.403,explained_var_new:0.450
# batch i:246, episode_len:3
# kl:0.02282,lr_multiplier:0.296,loss:3.06288480758667,entropy:2.52254056930542,explained_var_old:0.353,explained_var_new:0.389
# batch i:247, episode_len:3
# kl:0.01973,lr_multiplier:0.296,loss:3.311706066131592,entropy:2.670276165008545,explained_var_old:0.427,explained_var_new:0.445
# batch i:248, episode_len:3
# kl:0.03511,lr_multiplier:0.296,loss:3.302783727645874,entropy:2.8078553676605225,explained_var_old:0.404,explained_var_new:0.436
# batch i:249, episode_len:3
# kl:0.03994,lr_multiplier:0.296,loss:3.212090492248535,entropy:2.6327104568481445,explained_var_old:0.403,explained_var_new:0.439
# batch i:250, episode_len:3
# kl:0.02704,lr_multiplier:0.296,loss:3.1340749263763428,entropy:2.420280694961548,explained_var_old:0.303,explained_var_new:0.355
# current self-play batch: 250
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:251, episode_len:3
# kl:0.03543,lr_multiplier:0.296,loss:3.2019941806793213,entropy:2.7177016735076904,explained_var_old:0.373,explained_var_new:0.410
# batch i:252, episode_len:7
# kl:0.04457,lr_multiplier:0.198,loss:3.1393227577209473,entropy:2.603999614715576,explained_var_old:0.452,explained_var_new:0.490
# batch i:253, episode_len:3
# kl:0.01250,lr_multiplier:0.198,loss:3.321110963821411,entropy:2.6535072326660156,explained_var_old:0.366,explained_var_new:0.386
# batch i:254, episode_len:4
# kl:0.00601,lr_multiplier:0.296,loss:3.2386608123779297,entropy:2.627901315689087,explained_var_old:0.334,explained_var_new:0.354
# batch i:255, episode_len:3
# kl:0.01175,lr_multiplier:0.296,loss:3.192981719970703,entropy:2.7663047313690186,explained_var_old:0.414,explained_var_new:0.441
# batch i:256, episode_len:3
# kl:0.01877,lr_multiplier:0.296,loss:3.3216991424560547,entropy:2.714542865753174,explained_var_old:0.443,explained_var_new:0.471
# batch i:257, episode_len:4
# kl:0.01350,lr_multiplier:0.296,loss:3.125812530517578,entropy:2.592041015625,explained_var_old:0.414,explained_var_new:0.435
# batch i:258, episode_len:3
# kl:0.01451,lr_multiplier:0.296,loss:3.169731855392456,entropy:2.6100728511810303,explained_var_old:0.434,explained_var_new:0.472
# batch i:259, episode_len:3
# kl:0.01673,lr_multiplier:0.296,loss:3.3248298168182373,entropy:2.810265064239502,explained_var_old:0.337,explained_var_new:0.388
# batch i:260, episode_len:3
# kl:0.04468,lr_multiplier:0.198,loss:3.217677593231201,entropy:2.619809865951538,explained_var_old:0.403,explained_var_new:0.434
# current self-play batch: 260
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:261, episode_len:3
# kl:0.01113,lr_multiplier:0.198,loss:3.219822406768799,entropy:2.633734703063965,explained_var_old:0.443,explained_var_new:0.469
# batch i:262, episode_len:5
# kl:0.01475,lr_multiplier:0.198,loss:3.160109043121338,entropy:2.633269786834717,explained_var_old:0.402,explained_var_new:0.422
# batch i:263, episode_len:3
# kl:0.00816,lr_multiplier:0.296,loss:3.256328821182251,entropy:2.7593541145324707,explained_var_old:0.436,explained_var_new:0.469
# batch i:264, episode_len:3
# kl:0.02907,lr_multiplier:0.296,loss:3.1615359783172607,entropy:2.5850412845611572,explained_var_old:0.387,explained_var_new:0.432
# batch i:265, episode_len:5
# kl:0.01207,lr_multiplier:0.296,loss:3.307605266571045,entropy:2.767254590988159,explained_var_old:0.413,explained_var_new:0.437
# batch i:266, episode_len:3
# kl:0.02912,lr_multiplier:0.296,loss:3.2597146034240723,entropy:2.5939996242523193,explained_var_old:0.342,explained_var_new:0.381
# batch i:267, episode_len:3
# kl:0.02118,lr_multiplier:0.296,loss:3.066269874572754,entropy:2.555959463119507,explained_var_old:0.469,explained_var_new:0.502
# batch i:268, episode_len:3
# kl:0.00793,lr_multiplier:0.444,loss:3.2851366996765137,entropy:2.802379608154297,explained_var_old:0.462,explained_var_new:0.482
# batch i:269, episode_len:3
# kl:0.02626,lr_multiplier:0.444,loss:3.205584764480591,entropy:2.6680407524108887,explained_var_old:0.372,explained_var_new:0.444
# batch i:270, episode_len:3
# kl:0.02575,lr_multiplier:0.444,loss:3.264620542526245,entropy:2.6373283863067627,explained_var_old:0.377,explained_var_new:0.425
# current self-play batch: 270
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:271, episode_len:3
# kl:0.03234,lr_multiplier:0.444,loss:3.1476829051971436,entropy:2.6577985286712646,explained_var_old:0.396,explained_var_new:0.452
# batch i:272, episode_len:3
# kl:0.02685,lr_multiplier:0.444,loss:3.2480337619781494,entropy:2.714094638824463,explained_var_old:0.409,explained_var_new:0.449
# batch i:273, episode_len:3
# kl:0.03159,lr_multiplier:0.444,loss:3.104653835296631,entropy:2.5023787021636963,explained_var_old:0.402,explained_var_new:0.441
# batch i:274, episode_len:4
# kl:0.04554,lr_multiplier:0.296,loss:3.0277576446533203,entropy:2.5623559951782227,explained_var_old:0.415,explained_var_new:0.459
# batch i:275, episode_len:5
# kl:0.01306,lr_multiplier:0.296,loss:3.343217611312866,entropy:2.7510979175567627,explained_var_old:0.356,explained_var_new:0.383
# batch i:276, episode_len:3
# kl:0.01527,lr_multiplier:0.296,loss:3.3492469787597656,entropy:2.8005261421203613,explained_var_old:0.414,explained_var_new:0.450
# batch i:277, episode_len:3
# kl:0.01137,lr_multiplier:0.296,loss:3.1738011837005615,entropy:2.6071531772613525,explained_var_old:0.413,explained_var_new:0.452
# batch i:278, episode_len:3
# kl:0.01678,lr_multiplier:0.296,loss:3.234999418258667,entropy:2.6686315536499023,explained_var_old:0.419,explained_var_new:0.448
# batch i:279, episode_len:3
# kl:0.01157,lr_multiplier:0.296,loss:3.086348533630371,entropy:2.697643756866455,explained_var_old:0.506,explained_var_new:0.519
# batch i:280, episode_len:3
# kl:0.01658,lr_multiplier:0.296,loss:3.0890002250671387,entropy:2.5210065841674805,explained_var_old:0.450,explained_var_new:0.477
# current self-play batch: 280
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:281, episode_len:4
# kl:0.01235,lr_multiplier:0.296,loss:3.2128894329071045,entropy:2.6249685287475586,explained_var_old:0.334,explained_var_new:0.369
# batch i:282, episode_len:4
# kl:0.01818,lr_multiplier:0.296,loss:3.107950210571289,entropy:2.5679521560668945,explained_var_old:0.397,explained_var_new:0.444
# batch i:283, episode_len:3
# kl:0.01232,lr_multiplier:0.296,loss:3.335456609725952,entropy:2.820253372192383,explained_var_old:0.434,explained_var_new:0.470
# batch i:284, episode_len:3
# kl:0.03849,lr_multiplier:0.296,loss:3.111891031265259,entropy:2.571424961090088,explained_var_old:0.412,explained_var_new:0.460
# batch i:285, episode_len:3
# kl:0.01254,lr_multiplier:0.296,loss:3.1903765201568604,entropy:2.6227807998657227,explained_var_old:0.449,explained_var_new:0.469
# batch i:286, episode_len:3
# kl:0.01692,lr_multiplier:0.296,loss:3.1927900314331055,entropy:2.6606955528259277,explained_var_old:0.370,explained_var_new:0.411
# batch i:287, episode_len:4
# kl:0.03877,lr_multiplier:0.296,loss:3.0423779487609863,entropy:2.547175884246826,explained_var_old:0.454,explained_var_new:0.491
# batch i:288, episode_len:4
# kl:0.01686,lr_multiplier:0.296,loss:3.1514458656311035,entropy:2.5248210430145264,explained_var_old:0.431,explained_var_new:0.470
# batch i:289, episode_len:3
# kl:0.02029,lr_multiplier:0.296,loss:3.1926112174987793,entropy:2.7405107021331787,explained_var_old:0.441,explained_var_new:0.466
# batch i:290, episode_len:3
# kl:0.01515,lr_multiplier:0.296,loss:3.1667487621307373,entropy:2.5921547412872314,explained_var_old:0.359,explained_var_new:0.421
# current self-play batch: 290
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:291, episode_len:4
# kl:0.01540,lr_multiplier:0.296,loss:3.101086139678955,entropy:2.538395404815674,explained_var_old:0.431,explained_var_new:0.472
# batch i:292, episode_len:3
# kl:0.01946,lr_multiplier:0.296,loss:3.0855214595794678,entropy:2.569685220718384,explained_var_old:0.405,explained_var_new:0.440
# batch i:293, episode_len:6
# kl:0.01298,lr_multiplier:0.296,loss:3.148710012435913,entropy:2.600982189178467,explained_var_old:0.383,explained_var_new:0.429
# batch i:294, episode_len:3
# kl:0.02388,lr_multiplier:0.296,loss:3.0595316886901855,entropy:2.494591236114502,explained_var_old:0.409,explained_var_new:0.448
# batch i:295, episode_len:3
# kl:0.01298,lr_multiplier:0.296,loss:3.2339320182800293,entropy:2.595263719558716,explained_var_old:0.359,explained_var_new:0.415
# batch i:296, episode_len:4
# kl:0.00964,lr_multiplier:0.444,loss:3.2105908393859863,entropy:2.6585254669189453,explained_var_old:0.339,explained_var_new:0.385
# batch i:297, episode_len:3
# kl:0.01595,lr_multiplier:0.444,loss:3.2622060775756836,entropy:2.6633474826812744,explained_var_old:0.356,explained_var_new:0.402
# batch i:298, episode_len:3
# kl:0.02849,lr_multiplier:0.444,loss:3.233959197998047,entropy:2.6515581607818604,explained_var_old:0.370,explained_var_new:0.426
# batch i:299, episode_len:3
# kl:0.02548,lr_multiplier:0.444,loss:3.3315441608428955,entropy:2.757340908050537,explained_var_old:0.331,explained_var_new:0.385
# batch i:300, episode_len:3
# kl:0.02887,lr_multiplier:0.444,loss:3.3035292625427246,entropy:2.724355936050415,explained_var_old:0.406,explained_var_new:0.453
# current self-play batch: 300
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:301, episode_len:4
# kl:0.02929,lr_multiplier:0.444,loss:3.1784255504608154,entropy:2.6199002265930176,explained_var_old:0.318,explained_var_new:0.379
# batch i:302, episode_len:3
# kl:0.02340,lr_multiplier:0.444,loss:3.3369805812835693,entropy:2.7414777278900146,explained_var_old:0.391,explained_var_new:0.440
# batch i:303, episode_len:3
# kl:0.03439,lr_multiplier:0.444,loss:3.1847145557403564,entropy:2.524502992630005,explained_var_old:0.318,explained_var_new:0.368
# batch i:304, episode_len:3
# kl:0.02902,lr_multiplier:0.444,loss:3.19462251663208,entropy:2.6143722534179688,explained_var_old:0.337,explained_var_new:0.381
# batch i:305, episode_len:3
# kl:0.02551,lr_multiplier:0.444,loss:3.1459670066833496,entropy:2.6317598819732666,explained_var_old:0.418,explained_var_new:0.457
# batch i:306, episode_len:5
# kl:0.02143,lr_multiplier:0.444,loss:3.1545767784118652,entropy:2.598327159881592,explained_var_old:0.415,explained_var_new:0.453
# batch i:307, episode_len:3
# kl:0.03471,lr_multiplier:0.444,loss:3.2639105319976807,entropy:2.7557365894317627,explained_var_old:0.418,explained_var_new:0.457
# batch i:308, episode_len:3
# kl:0.01828,lr_multiplier:0.444,loss:3.055997371673584,entropy:2.5444302558898926,explained_var_old:0.406,explained_var_new:0.450
# batch i:309, episode_len:3
# kl:0.03187,lr_multiplier:0.444,loss:3.111262798309326,entropy:2.5541417598724365,explained_var_old:0.432,explained_var_new:0.484
# batch i:310, episode_len:4
# kl:0.02047,lr_multiplier:0.444,loss:3.226264476776123,entropy:2.715055465698242,explained_var_old:0.438,explained_var_new:0.476
# current self-play batch: 310
# num_playouts:1000, win: 5, lose: 5, tie:0
# ...
# batch i:1404, episode_len:3
# kl:0.02001,lr_multiplier:1.000,loss:3.1608269214630127,entropy:2.669006109237671,explained_var_old:0.477,explained_var_new:0.519
# batch i:1405, episode_len:5
# kl:0.02772,lr_multiplier:1.000,loss:2.838768720626831,entropy:2.3636815547943115,explained_var_old:0.496,explained_var_new:0.547
# batch i:1406, episode_len:3
# kl:0.01787,lr_multiplier:1.000,loss:2.985980749130249,entropy:2.4633805751800537,explained_var_old:0.431,explained_var_new:0.495
# batch i:1407, episode_len:3
# kl:0.02222,lr_multiplier:1.000,loss:2.928734540939331,entropy:2.438417911529541,explained_var_old:0.461,explained_var_new:0.515
# batch i:1408, episode_len:3
# kl:0.01958,lr_multiplier:1.000,loss:2.9061167240142822,entropy:2.414682388305664,explained_var_old:0.454,explained_var_new:0.509
# batch i:1409, episode_len:5
# kl:0.02436,lr_multiplier:1.000,loss:2.9269461631774902,entropy:2.419095277786255,explained_var_old:0.432,explained_var_new:0.497
# batch i:1410, episode_len:3
# kl:0.02259,lr_multiplier:1.000,loss:2.941351890563965,entropy:2.4719982147216797,explained_var_old:0.466,explained_var_new:0.498
# current self-play batch: 1410
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1411, episode_len:4
# kl:0.02134,lr_multiplier:1.000,loss:2.982856273651123,entropy:2.5056867599487305,explained_var_old:0.514,explained_var_new:0.551
# batch i:1412, episode_len:3
# kl:0.02498,lr_multiplier:1.000,loss:2.7898640632629395,entropy:2.3468446731567383,explained_var_old:0.549,explained_var_new:0.609
# batch i:1413, episode_len:3
# kl:0.02904,lr_multiplier:1.000,loss:2.814206123352051,entropy:2.327812910079956,explained_var_old:0.453,explained_var_new:0.513
# batch i:1414, episode_len:3
# kl:0.01898,lr_multiplier:1.000,loss:2.9688069820404053,entropy:2.4889955520629883,explained_var_old:0.476,explained_var_new:0.523
# batch i:1415, episode_len:3
# kl:0.02886,lr_multiplier:1.000,loss:2.9023473262786865,entropy:2.3623604774475098,explained_var_old:0.450,explained_var_new:0.510
# batch i:1416, episode_len:3
# kl:0.02662,lr_multiplier:1.000,loss:3.0570950508117676,entropy:2.561184883117676,explained_var_old:0.424,explained_var_new:0.484
# batch i:1417, episode_len:3
# kl:0.03054,lr_multiplier:1.000,loss:2.775524139404297,entropy:2.3174996376037598,explained_var_old:0.542,explained_var_new:0.567
# batch i:1418, episode_len:3
# kl:0.02257,lr_multiplier:1.000,loss:2.9453532695770264,entropy:2.40407133102417,explained_var_old:0.385,explained_var_new:0.448
# batch i:1419, episode_len:3
# kl:0.01372,lr_multiplier:1.000,loss:2.994861364364624,entropy:2.509326696395874,explained_var_old:0.444,explained_var_new:0.491
# batch i:1420, episode_len:3
# kl:0.01839,lr_multiplier:1.000,loss:2.8582632541656494,entropy:2.3141849040985107,explained_var_old:0.401,explained_var_new:0.472
# current self-play batch: 1420
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1421, episode_len:3
# kl:0.03467,lr_multiplier:1.000,loss:2.773285150527954,entropy:2.3059377670288086,explained_var_old:0.477,explained_var_new:0.525
# batch i:1422, episode_len:3
# kl:0.01720,lr_multiplier:1.000,loss:3.032134532928467,entropy:2.515749931335449,explained_var_old:0.463,explained_var_new:0.497
# batch i:1423, episode_len:5
# kl:0.01859,lr_multiplier:1.000,loss:3.023991346359253,entropy:2.533763885498047,explained_var_old:0.495,explained_var_new:0.526
# batch i:1424, episode_len:3
# kl:0.01941,lr_multiplier:1.000,loss:2.8605997562408447,entropy:2.4538750648498535,explained_var_old:0.572,explained_var_new:0.618
# batch i:1425, episode_len:4
# kl:0.02441,lr_multiplier:1.000,loss:2.88726544380188,entropy:2.3619039058685303,explained_var_old:0.431,explained_var_new:0.475
# batch i:1426, episode_len:3
# kl:0.01491,lr_multiplier:1.000,loss:2.95460844039917,entropy:2.454098701477051,explained_var_old:0.473,explained_var_new:0.512
# batch i:1427, episode_len:3
# kl:0.02602,lr_multiplier:1.000,loss:2.8438355922698975,entropy:2.314819812774658,explained_var_old:0.419,explained_var_new:0.474
# batch i:1428, episode_len:3
# kl:0.03471,lr_multiplier:1.000,loss:2.859572410583496,entropy:2.3805196285247803,explained_var_old:0.453,explained_var_new:0.503
# batch i:1429, episode_len:3
# kl:0.01558,lr_multiplier:1.000,loss:2.893894672393799,entropy:2.3798317909240723,explained_var_old:0.438,explained_var_new:0.475
# batch i:1430, episode_len:3
# kl:0.02543,lr_multiplier:1.000,loss:2.8434011936187744,entropy:2.3843748569488525,explained_var_old:0.530,explained_var_new:0.580
# current self-play batch: 1430
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1431, episode_len:4
# kl:0.01259,lr_multiplier:1.000,loss:2.980238676071167,entropy:2.421261787414551,explained_var_old:0.404,explained_var_new:0.468
# batch i:1432, episode_len:3
# kl:0.01760,lr_multiplier:1.000,loss:2.9094691276550293,entropy:2.420384168624878,explained_var_old:0.440,explained_var_new:0.489
# batch i:1433, episode_len:3
# kl:0.02023,lr_multiplier:1.000,loss:2.772644519805908,entropy:2.320763349533081,explained_var_old:0.468,explained_var_new:0.519
# batch i:1434, episode_len:5
# kl:0.02795,lr_multiplier:1.000,loss:2.7742912769317627,entropy:2.3199939727783203,explained_var_old:0.511,explained_var_new:0.547
# batch i:1435, episode_len:3
# kl:0.02976,lr_multiplier:1.000,loss:3.0013129711151123,entropy:2.4257493019104004,explained_var_old:0.378,explained_var_new:0.428
# batch i:1436, episode_len:5
# kl:0.04279,lr_multiplier:0.667,loss:2.7229788303375244,entropy:2.234192132949829,explained_var_old:0.439,explained_var_new:0.470
# batch i:1437, episode_len:3
# kl:0.01818,lr_multiplier:0.667,loss:2.9879231452941895,entropy:2.455118179321289,explained_var_old:0.457,explained_var_new:0.484
# batch i:1438, episode_len:3
# kl:0.01760,lr_multiplier:0.667,loss:2.9389007091522217,entropy:2.422804355621338,explained_var_old:0.438,explained_var_new:0.471
# batch i:1439, episode_len:3
# kl:0.00807,lr_multiplier:1.000,loss:2.8731298446655273,entropy:2.4170191287994385,explained_var_old:0.496,explained_var_new:0.517
# batch i:1440, episode_len:3
# kl:0.02354,lr_multiplier:1.000,loss:2.6753039360046387,entropy:2.1698737144470215,explained_var_old:0.469,explained_var_new:0.506
# current self-play batch: 1440
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1441, episode_len:3
# kl:0.02142,lr_multiplier:1.000,loss:2.8255066871643066,entropy:2.3895657062530518,explained_var_old:0.534,explained_var_new:0.577
# batch i:1442, episode_len:3
# kl:0.02103,lr_multiplier:1.000,loss:2.8474538326263428,entropy:2.3559627532958984,explained_var_old:0.474,explained_var_new:0.509
# batch i:1443, episode_len:3
# kl:0.01951,lr_multiplier:1.000,loss:3.0851213932037354,entropy:2.5538454055786133,explained_var_old:0.438,explained_var_new:0.478
# batch i:1444, episode_len:3
# kl:0.01307,lr_multiplier:1.000,loss:2.7535877227783203,entropy:2.3372833728790283,explained_var_old:0.553,explained_var_new:0.593
# batch i:1445, episode_len:3
# kl:0.01734,lr_multiplier:1.000,loss:2.8703417778015137,entropy:2.433203935623169,explained_var_old:0.565,explained_var_new:0.609
# batch i:1446, episode_len:3
# kl:0.02060,lr_multiplier:1.000,loss:2.798921823501587,entropy:2.438377857208252,explained_var_old:0.590,explained_var_new:0.639
# batch i:1447, episode_len:3
# kl:0.01572,lr_multiplier:1.000,loss:2.9106831550598145,entropy:2.3722376823425293,explained_var_old:0.417,explained_var_new:0.471
# batch i:1448, episode_len:3
# kl:0.02130,lr_multiplier:1.000,loss:2.7780635356903076,entropy:2.3428030014038086,explained_var_old:0.542,explained_var_new:0.590
# batch i:1449, episode_len:5
# kl:0.03704,lr_multiplier:1.000,loss:2.8891756534576416,entropy:2.420718193054199,explained_var_old:0.462,explained_var_new:0.509
# batch i:1450, episode_len:4
# kl:0.01726,lr_multiplier:1.000,loss:2.842947483062744,entropy:2.3985986709594727,explained_var_old:0.502,explained_var_new:0.550
# current self-play batch: 1450
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1451, episode_len:6
# kl:0.02228,lr_multiplier:1.000,loss:2.8827977180480957,entropy:2.3946115970611572,explained_var_old:0.473,explained_var_new:0.509
# batch i:1452, episode_len:3
# kl:0.01683,lr_multiplier:1.000,loss:2.722939968109131,entropy:2.2679858207702637,explained_var_old:0.492,explained_var_new:0.549
# batch i:1453, episode_len:3
# kl:0.02935,lr_multiplier:1.000,loss:2.917616128921509,entropy:2.42014741897583,explained_var_old:0.407,explained_var_new:0.469
# batch i:1454, episode_len:3
# kl:0.01871,lr_multiplier:1.000,loss:2.9526538848876953,entropy:2.4300174713134766,explained_var_old:0.453,explained_var_new:0.492
# batch i:1455, episode_len:3
# kl:0.01773,lr_multiplier:1.000,loss:3.0088460445404053,entropy:2.4770426750183105,explained_var_old:0.453,explained_var_new:0.492
# batch i:1456, episode_len:3
# kl:0.02134,lr_multiplier:1.000,loss:2.9484541416168213,entropy:2.4154958724975586,explained_var_old:0.431,explained_var_new:0.472
# batch i:1457, episode_len:3
# kl:0.01845,lr_multiplier:1.000,loss:2.912623643875122,entropy:2.4765803813934326,explained_var_old:0.537,explained_var_new:0.568
# batch i:1458, episode_len:4
# kl:0.01918,lr_multiplier:1.000,loss:3.02154278755188,entropy:2.4515817165374756,explained_var_old:0.418,explained_var_new:0.452
# batch i:1459, episode_len:3
# kl:0.02386,lr_multiplier:1.000,loss:2.873260021209717,entropy:2.403770923614502,explained_var_old:0.533,explained_var_new:0.564
# batch i:1460, episode_len:3
# kl:0.01647,lr_multiplier:1.000,loss:2.851548671722412,entropy:2.376833200454712,explained_var_old:0.467,explained_var_new:0.529
# current self-play batch: 1460
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1461, episode_len:3
# kl:0.02274,lr_multiplier:1.000,loss:2.8623898029327393,entropy:2.3464560508728027,explained_var_old:0.428,explained_var_new:0.476
# batch i:1462, episode_len:4
# kl:0.03077,lr_multiplier:1.000,loss:2.9454586505889893,entropy:2.3865950107574463,explained_var_old:0.436,explained_var_new:0.484
# batch i:1463, episode_len:3
# kl:0.02725,lr_multiplier:1.000,loss:2.9145779609680176,entropy:2.3800923824310303,explained_var_old:0.441,explained_var_new:0.484
# batch i:1464, episode_len:3
# kl:0.01883,lr_multiplier:1.000,loss:2.849061965942383,entropy:2.4137558937072754,explained_var_old:0.493,explained_var_new:0.551
# batch i:1465, episode_len:3
# kl:0.01455,lr_multiplier:1.000,loss:2.750279664993286,entropy:2.2645394802093506,explained_var_old:0.491,explained_var_new:0.532
# batch i:1466, episode_len:3
# kl:0.02355,lr_multiplier:1.000,loss:2.763298749923706,entropy:2.27848482131958,explained_var_old:0.482,explained_var_new:0.518
# batch i:1467, episode_len:3
# kl:0.01335,lr_multiplier:1.000,loss:2.782597303390503,entropy:2.244770050048828,explained_var_old:0.425,explained_var_new:0.478
# batch i:1468, episode_len:3
# kl:0.02845,lr_multiplier:1.000,loss:2.8556556701660156,entropy:2.2893776893615723,explained_var_old:0.363,explained_var_new:0.443
# batch i:1469, episode_len:3
# kl:0.01417,lr_multiplier:1.000,loss:2.9264400005340576,entropy:2.470737934112549,explained_var_old:0.533,explained_var_new:0.577
# batch i:1470, episode_len:3
# kl:0.02490,lr_multiplier:1.000,loss:2.8314828872680664,entropy:2.360220432281494,explained_var_old:0.480,explained_var_new:0.522
# current self-play batch: 1470
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1471, episode_len:3
# kl:0.02866,lr_multiplier:1.000,loss:2.8873157501220703,entropy:2.364365577697754,explained_var_old:0.413,explained_var_new:0.469
# batch i:1472, episode_len:3
# kl:0.02375,lr_multiplier:1.000,loss:2.9857735633850098,entropy:2.4779040813446045,explained_var_old:0.487,explained_var_new:0.514
# batch i:1473, episode_len:3
# kl:0.02184,lr_multiplier:1.000,loss:2.7424476146698,entropy:2.321028709411621,explained_var_old:0.528,explained_var_new:0.590
# batch i:1474, episode_len:3
# kl:0.02076,lr_multiplier:1.000,loss:2.9303841590881348,entropy:2.413167953491211,explained_var_old:0.459,explained_var_new:0.498
# batch i:1475, episode_len:3
# kl:0.02218,lr_multiplier:1.000,loss:2.8768415451049805,entropy:2.4510498046875,explained_var_old:0.522,explained_var_new:0.563
# batch i:1476, episode_len:3
# kl:0.01754,lr_multiplier:1.000,loss:2.907973051071167,entropy:2.4386699199676514,explained_var_old:0.487,explained_var_new:0.526
# batch i:1477, episode_len:3
# kl:0.01992,lr_multiplier:1.000,loss:2.8927159309387207,entropy:2.368485927581787,explained_var_old:0.455,explained_var_new:0.510
# batch i:1478, episode_len:3
# kl:0.01305,lr_multiplier:1.000,loss:2.812572479248047,entropy:2.397996664047241,explained_var_old:0.569,explained_var_new:0.608
# batch i:1479, episode_len:4
# kl:0.01219,lr_multiplier:1.000,loss:2.8849315643310547,entropy:2.4000558853149414,explained_var_old:0.478,explained_var_new:0.510
# batch i:1480, episode_len:3
# kl:0.02758,lr_multiplier:1.000,loss:2.8786277770996094,entropy:2.3771300315856934,explained_var_old:0.478,explained_var_new:0.512
# current self-play batch: 1480
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1481, episode_len:3
# kl:0.02182,lr_multiplier:1.000,loss:2.7567124366760254,entropy:2.272801399230957,explained_var_old:0.483,explained_var_new:0.517
# batch i:1482, episode_len:3
# kl:0.01583,lr_multiplier:1.000,loss:2.9010326862335205,entropy:2.4456496238708496,explained_var_old:0.507,explained_var_new:0.542
# batch i:1483, episode_len:3
# kl:0.02421,lr_multiplier:1.000,loss:2.820080518722534,entropy:2.305628538131714,explained_var_old:0.431,explained_var_new:0.482
# batch i:1484, episode_len:3
# kl:0.01489,lr_multiplier:1.000,loss:2.859955072402954,entropy:2.4166531562805176,explained_var_old:0.502,explained_var_new:0.538
# batch i:1485, episode_len:5
# kl:0.01980,lr_multiplier:1.000,loss:2.733466863632202,entropy:2.3024375438690186,explained_var_old:0.555,explained_var_new:0.579
# batch i:1486, episode_len:4
# kl:0.01887,lr_multiplier:1.000,loss:2.6733076572418213,entropy:2.2821083068847656,explained_var_old:0.575,explained_var_new:0.605
# batch i:1487, episode_len:3
# kl:0.01705,lr_multiplier:1.000,loss:2.730416774749756,entropy:2.301973819732666,explained_var_old:0.521,explained_var_new:0.558
# batch i:1488, episode_len:5
# kl:0.01940,lr_multiplier:1.000,loss:2.872466564178467,entropy:2.3784680366516113,explained_var_old:0.474,explained_var_new:0.512
# batch i:1489, episode_len:3
# kl:0.01479,lr_multiplier:1.000,loss:2.9129955768585205,entropy:2.4393434524536133,explained_var_old:0.507,explained_var_new:0.540
# batch i:1490, episode_len:4
# kl:0.01833,lr_multiplier:1.000,loss:2.905791759490967,entropy:2.4426021575927734,explained_var_old:0.517,explained_var_new:0.555
# current self-play batch: 1490
# num_playouts:1000, win: 5, lose: 5, tie:0
# batch i:1491, episode_len:3
# kl:0.02766,lr_multiplier:1.000,loss:2.799612283706665,entropy:2.3125410079956055,explained_var_old:0.501,explained_var_new:0.532
# batch i:1492, episode_len:3
# kl:0.01111,lr_multiplier:1.000,loss:2.8033907413482666,entropy:2.2968497276306152,explained_var_old:0.442,explained_var_new:0.500
# batch i:1493, episode_len:5
# kl:0.01703,lr_multiplier:1.000,loss:2.9612386226654053,entropy:2.4431581497192383,explained_var_old:0.444,explained_var_new:0.475
# batch i:1494, episode_len:3
# kl:0.02530,lr_multiplier:1.000,loss:2.8306331634521484,entropy:2.3472914695739746,explained_var_old:0.467,explained_var_new:0.516
# batch i:1495, episode_len:3
# kl:0.02269,lr_multiplier:1.000,loss:2.89729642868042,entropy:2.430746555328369,explained_var_old:0.510,explained_var_new:0.551
# batch i:1496, episode_len:3
# kl:0.01875,lr_multiplier:1.000,loss:2.7367465496063232,entropy:2.319561004638672,explained_var_old:0.522,explained_var_new:0.573
# batch i:1497, episode_len:3
# kl:0.02384,lr_multiplier:1.000,loss:2.953192949295044,entropy:2.537759780883789,explained_var_old:0.582,explained_var_new:0.602
# batch i:1498, episode_len:3
# kl:0.01690,lr_multiplier:1.000,loss:2.913292407989502,entropy:2.4447879791259766,explained_var_old:0.516,explained_var_new:0.553
# batch i:1499, episode_len:4
# kl:0.01224,lr_multiplier:1.000,loss:2.809461832046509,entropy:2.4222240447998047,explained_var_old:0.578,explained_var_new:0.620
# batch i:1500, episode_len:3
# kl:0.02112,lr_multiplier:1.000,loss:2.8774473667144775,entropy:2.389138698577881,explained_var_old:0.504,explained_var_new:0.549
# current self-play batch: 1500
# num_playouts:1000, win: 5, lose: 5, tie:0

# %% [markdown]
# ## On a few technical details in the Gomoku Implementations

# %% [markdown]
# ### Data augmentation via rotation/flipping
#
# The game state is invariant under rotating the board or flipping the game state at one of the axes of symmetry. Hence we can simulate data based on these transformations.
#
# ```python
# def get_equi_data(self, play_data):
#     """augment the data set by rotation and flipping
#     play_data: [(state, mcts_prob, winner_z), ..., ...]
#     """
#     extend_data = []
#     for state, mcts_porb, winner in play_data:
#         for i in [1, 2, 3, 4]:
#             # rotate counterclockwise
#             equi_state = np.array([np.rot90(s, i) for s in state])
#             equi_mcts_prob = np.rot90(np.flipud(
#                 mcts_prob.reshape(self.board_height, self.board_width)), i)
#             extend_data.append((equi_state,
#                                 np.flipud(equi_mcts_prob).flatten(),
#                                 winner))
#             # flip horizontally
#             equi_state = np.array([np.fliplr(s) for s in equi_state])
#             equi_mcts_prob = np.fliplr(equi_mcts_prob)
#             extend_data.append((equi_state,
#                                 np.flipud(equi_mcts_prob).flatten(),
#                                 winner))
#     return extend_data
# ```
